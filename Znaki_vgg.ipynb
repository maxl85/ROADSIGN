# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import numpy as np
import pandas as pd
from keras.models import model_from_json
from PIL import Image
import keras.preprocessing.image as kp
import os
from PIL import Image
from keras.models import Sequential,Graph
from keras.layers.core import Activation,Flatten, Dense, Dropout,Reshape
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
import keras.preprocessing.image as kp
from keras.models import model_from_json
import h5py
# Out:
# Using Theano backend.
# INFO (theano.gof.compilelock): Waiting for existing lock by process '18488' (I am process '17184')
# INFO:theano.gof.compilelock:Waiting for existing lock by process '18488' (I am process '17184')
# INFO (theano.gof.compilelock): To manually release the lock, delete C:\Users\������\AppData\Local\Theano\compiledir_Windows-8-6.2.9200-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.10-64\lock_dir
# INFO:theano.gof.compilelock:To manually release the lock, delete C:\Users\������\AppData\Local\Theano\compiledir_Windows-8-6.2.9200-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.10-64\lock_dir
# DEBUG: nvcc STDOUT mod.cu
# ...

# %%
img_size = 32

# %%
model = Sequential()
model.add(ZeroPadding2D((1,1),input_shape=(3,32,32)))
model.add(Convolution2D(64, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(64, 3, 3, activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, 3, 3, activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, 3, 3, activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, 3, 3, activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, 3, 3, activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, 3, 3, activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

# %%
f = h5py.File('Keras/examples/vgg16_weights.h5')
for k in range(f.attrs['nb_layers']):
    if k >= len(model.layers):
        # we don't look at the last (fully-connected) layers in the savefile
        break
    g = f['layer_{}'.format(k)]
    weights = [g['param_{}'.format(p)] for p in range(g.attrs['nb_params'])]
    model.layers[k].set_weights(weights)
f.close()


sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
model.compile(optimizer=sgd, loss='categorical_crossentropy')

# %%
train_data_dir = 'data_train'
validation_data_dir = 'data_test'
nb_train_samples = 84347
nb_validation_samples = 21948

# %%
train_data_dir = 'Znaki_multiclass\Train'
validation_data_dir = 'Znaki_multiclass\Test'
nb_train_samples = 52700
nb_validation_samples = 2213

# %%
datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)
generator = datagen.flow_from_directory(
            train_data_dir,
            target_size=(img_size, img_size),
            batch_size=32,
            class_mode=None,
            shuffle=False)
bottleneck_features_train = model.predict_generator(generator, nb_train_samples)
trgen = generator

generator = datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_size, img_size),
        batch_size=32,
        class_mode=None,
        shuffle=False)
bottleneck_features_validation = model.predict_generator(generator, nb_validation_samples)
# Out:
# Found 52700 images belonging to 44 classes.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-fde87484b0b4> in <module>()
#      10             class_mode=None,
#      11             shuffle=False)
# ---> 12 bottleneck_features_train = model.predict_generator(generator, nb_train_samples)
#      13 trgen = generator
#      14
#
# D:\WinPython-64bit-2.7.10.3\python-2.7.10.amd64\lib\site-packages\keras\models.pyc in predict_generator(self, generator, val_samples, max_q_size)
#     705             self.build()
#     706         return self.model.predict_generator(generator, val_samples,
# --> 707                                             max_q_size=max_q_size)
#     708
#     709     def get_config(self):
#
# D:\WinPython-64bit-2.7.10.3\python-2.7.10.amd64\lib\site-packages\keras\engine\training.pyc in predict_generator(self, generator, val_samples, max_q_size)
# ...

# %%
datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)
generator = datagen.flow_from_directory(
            train_data_dir,
            target_size=(img_size, img_size),
            batch_size=32,
            class_mode='categorical',
            shuffle=False)
bottleneck_features_train = model.predict_generator(generator, nb_train_samples)
trgen = generator

generator = datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_size, img_size),
        batch_size=32,
        class_mode='categorical',
        shuffle=False)
bottleneck_features_validation = model.predict_generator(generator, nb_validation_samples)
# Out:
# Found 52700 images belonging to 44 classes.
# Found 2213 images belonging to 44 classes.

# %%
generator.class_indices
# Out:
# {'negativ': 0, 'znaki': 1}

# %%
# the features were saved in order, so recreating the labels is easy
train_labels = np.array([0] * 42045 + [1] * 42302)

validation_labels = np.array([0] * 8448 + [1] * 13500)

tmodel = Sequential()
tmodel.add(Flatten(input_shape=bottleneck_features_train.shape[1:]))
tmodel.add(Dense(64, activation='relu'))
tmodel.add(Dropout(0.5))
tmodel.add(Dense(1, activation='sigmoid'))

tmodel.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

tmodel.fit(bottleneck_features_train, train_labels,
          nb_epoch=50, batch_size=32,
          validation_data=(bottleneck_features_validation, validation_labels))
#tmodel.save_weights('bottleneck_fc_model.h5')
# Out:
# Train on 84347 samples, validate on 21948 samples
# Epoch 1/50
# 84347/84347 [==============================] - 7s - loss: 0.2017 - acc: 0.9195 - val_loss: 0.1704 - val_acc: 0.9384
# Epoch 2/50
# 84347/84347 [==============================] - 7s - loss: 0.1761 - acc: 0.9347 - val_loss: 0.1943 - val_acc: 0.9348
# Epoch 3/50
# 84347/84347 [==============================] - 8s - loss: 0.1720 - acc: 0.9390 - val_loss: 0.1836 - val_acc: 0.9398
# Epoch 4/50
# 84347/84347 [==============================] - 8s - loss: 0.1713 - acc: 0.9408 - val_loss: 0.1644 - val_acc: 0.9479
# Epoch 5/50
# 84347/84347 [==============================] - 6s - loss: 0.1693 - acc: 0.9420 - val_loss: 0.1587 - val_acc: 0.9500
# Epoch 6/50
# 84347/84347 [==============================] - 7s - loss: 0.1679 - acc: 0.9437 - val_loss: 0.1643 - val_acc: 0.9496
# Epoch 7/50
# 84347/84347 [==============================] - 7s - loss: 0.1671 - acc: 0.9441 - val_loss: 0.1825 - val_acc: 0.9437
# Epoch 8/50
# ...

# %%
len(trgen.classes)
# Out:
# 52700

# %%
num_train = np.zeros((44))
c = 0
cc = 0 
for i in range(44):
    for cl in trgen.classes:
        if cl == c:
            num_train[c]+=1
            cc+=1
    c+=1
 
num_test = np.zeros((44))
c = 0
for i in range(44):
    for cl in generator.classes:
        if cl == c:
            num_test[c]+=1
            
    c+=1
cc
# Out:
# 52700

# %%
num_test.reshape(1,0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-d7fdb29d758a> in <module>()
# ----> 1 num_test.reshape(1,0)
#
# ValueError: total size of new array must be unchanged

# %%
# the features were saved in order, so recreating the labels is easy
train_labels = np.array([0] * num_train[0] + [1] * num_train[1] +[2] * num_train[2] +[3] * num_train[3] +[4] * num_train[4] +
                       [5] * num_train[5] +[6] * num_train[6] +[7] * num_train[7] +[8] * num_train[8] +[9] * num_train[9] +
                       [10] * num_train[10] +[11] * num_train[11] +[12] * num_train[12] +[13] * num_train[13] +[14] * num_train[14] +
                       [15] * num_train[15] +[16] * num_train[16] +[17] * num_train[17] +[18] * num_train[18] +[19] * num_train[19] +
                       [20] * num_train[20] +[21] * num_train[21] +[22] * num_train[22] +[23] * num_train[23] +[24] * num_train[24] +
                       [25] * num_train[25] +[26] * num_train[26] +[27] * num_train[27] +[28] * num_train[28] +[29] * num_train[29] +
                       [30] * num_train[30] +[31] * num_train[31] +[32] * num_train[32] +[33] * num_train[33] +[34] * num_train[34] +
                       [35] * num_train[35] +[36] * num_train[36] +[37] * num_train[37] +[38] * num_train[38] +[39] * num_train[39] +
                       [40] * num_train[40] +[41] * num_train[41] +[42] * num_train[42] +[43] * num_train[43])

validation_labels = np.array([0] * num_test[0] + [1] * num_test[1] +[2] * num_test[2] +[3] * num_test[3] +[4] * num_test[4] +
                       [5] * num_test[5] +[6] * num_test[6] +[7] * num_test[7] +[8] * num_test[8] +[9] * num_test[9] +
                       [10] * num_test[10] +[11] * num_test[11] +[12] * num_test[12] +[13] * num_test[13] +[14] * num_test[14] +
                       [15] * num_test[15] +[16] * num_test[16] +[17] * num_test[17] +[18] * num_test[18] +[19] * num_test[19] +
                       [20] * num_test[20] +[21] * num_test[21] +[22] * num_test[22] +[23] * num_test[23] +[24] * num_test[24] +
                       [25] * num_test[25] +[26] * num_test[26] +[27] * num_test[27] +[28] * num_test[28] +[29] * num_test[29] +
                       [30] * num_test[30] +[31] * num_test[31] +[32] * num_test[32] +[33] * num_test[33] +[34] * num_test[34] +
                       [35] * num_test[35] +[36] * num_test[36] +[37] * num_test[37] +[38] * num_test[38] +[39] * num_test[39] +
                       [40] * num_test[40] +[41] * num_test[41] +[42] * num_test[42] +[43] * num_test[43])
# Out:
# (44L,)

# %%
tmodel = Sequential()
tmodel.add(Flatten(input_shape=bottleneck_features_train.shape[1:]))
tmodel.add(Dense(256, activation='relu'))
tmodel.add(Dropout(0.5))
tmodel.add(Dense(44, activation='softmax'))

tmodel.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

tmodel.fit(bottleneck_features_train, num_train,
          nb_epoch=50, batch_size=32,
          validation_data=(bottleneck_features_validation, num_test))
#tmodel.save_weights('bottleneck_fc_model.h5')
# Out:
# D:\WinPython-64bit-2.7.10.3\python-2.7.10.amd64\lib\site-packages\ipykernel\__main__.py:11: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# D:\WinPython-64bit-2.7.10.3\python-2.7.10.amd64\lib\site-packages\ipykernel\__main__.py:21: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-30-c901eb6ca4ce> in <module>()
#      33 tmodel.fit(bottleneck_features_train, num_train,
#      34           nb_epoch=50, batch_size=32,
# ---> 35           validation_data=(bottleneck_features_validation, num_test))
#      36 #tmodel.save_weights('bottleneck_fc_model.h5')
#
# ...

# %%
model.add(tmodel)

# %%
model_json = model.to_json()
with open("model_vgg.json", "w") as json_file:
    json_file.write(model_json)

# %%
model.save_weights('znaki_vgg.h5')

# %%
Fname = 'FullIJCNN2013'
Fnames = os.listdir(Fname)
count = 0
c = 0
for name in Fnames:
    fname = 'FullIJCNN2013/'+name
    mser = cv2.MSER_create(_delta=1)
    img = cv2.imread(fname)
    image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    mser_areas = mser.detectRegions(image,None)


    padding = 5
    windows_list = []
    for blob in mser_areas:
        df_blob = pd.DataFrame(blob)
        xmin, ymin = df_blob.min(0)
        xmax, ymax = df_blob.max(0)

        xmin -= padding
        ymin -= padding
        xmax += padding
        ymax += padding

        if xmin >= 0 and ymin >= 0 and xmax <= img.shape[1] and ymax <= img.shape[0]:
            windows_list.append((xmin, ymin, xmax, ymax))


    minSize=16
    maxSize=200
    maxProportion=1.2
    valid_windows = []
    for window in windows_list:
        size_x = float(window[2] - window[0])
        size_y = float(window[3] - window[1])
        if size_x < minSize or size_y < minSize or size_x > maxSize or size_y > maxSize or\
        size_x / size_y > maxProportion or size_y / size_x > maxProportion:
            continue
        valid_windows.append(window)


    #усредняет рамки
    windows = valid_windows
    if len(windows) == 1:
        print "Bred"
    else:
        epsilon = 20

        groups = {}
        indexes = range(len(windows))
        i = 0
        while i < len(windows):
            groups[i] = [i]
            indexes.remove(i)
            to_remove = []
            for j in indexes:
                if (np.abs(np.array(windows[i]) - np.array(windows[j])) < epsilon).all():
                    groups[i].append(j)
                    to_remove.append(j)
            for k in to_remove:
                indexes.remove(k)
            if indexes:
                i = indexes[0]
            else:
                break

        res_windows = []
        for key in groups:
            xmin = np.min([windows[ind][0] for ind in groups[key]])
            ymin = np.min([windows[ind][1] for ind in groups[key]])
            xmax = np.max([windows[ind][2] for ind in groups[key]])
            ymax = np.max([windows[ind][3] for ind in groups[key]])
            res_windows.append((xmin, ymin, xmax, ymax))


    #prediction
    img = plt.imread(fname)

    prediction = []
    
    for window in res_windows:
        B = img[int(window[1]):int(window[3]),int(window[0]):int(window[2])]
        A = B
        B = cv2.resize(B,(32,32))
        B = B.transpose(2,0,1)
        B = np.expand_dims(B, axis=0)
        predict = model.predict_classes(B)
        print predict [0][0]
        if predict [0][0] ==1:
            prediction.append(window)
            #I = Image.fromarray(A)
            #p='nn/z'+'/'+str(c)+'.jpg'
            c+=1
            #I.save(p)
        

    frames = prediction
    for frame in frames:
        coords = (frame[0], frame[1]), (frame[2], frame[3])
        cv2.rectangle(img, (frame[0], frame[1]),(frame[2], frame[3]),(0,0,255), 2)
    path_save = 'res/vgg/'+str(count)+'.jpg'
    cv2.imwrite(path_save,img)
    count+=1

# %%
p = "data_train/znaki"
p = p.strip()
List = os.listdir(p)
c = 0
for l in List:
    p = 'data_train/znaki/'+l
    fil = kp.load_img(p)
    im = fil.resize((32,32))
    im = kp.img_to_array(im)
    im = np.expand_dims(im, axis=0)
    predict = model.predict_classes(im)
    if predict[0][0]==0:
        c+=1
print c
# Out:
# ...
# 1/1 [==============================] - 0s
# ...
# ...
# 1/1 [==============================] - 0s
# 1612
